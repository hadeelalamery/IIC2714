# %%
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 10)

import matplotlib.pyplot as plt
import numpy as np

import fct

from collections import Counter
from scipy import misc
from sklearn import cluster

from skimage.measure import label
from skimage.morphology import remove_small_objects, dilation, disk

from skimage.exposure import equalize_adapthist

# Clean iris
from skimage.morphology import convex_hull_image, binary_erosion, dilation, erosion

# Find center
from scipy.signal import convolve2d as conv2

# Hough transform
from skimage import color
from skimage.feature import peak_local_max, canny
from skimage.transform import hough_circle
from skimage.draw import ellipse_perimeter
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def read_img(nb, eye, img_nb):
    folder = 'input/IR/'
    file = folder + nb + '/' + nb + '_' + eye + '/'
    file += 'Img_' + nb + '_' + eye + '_' + img_nb + '.bmp'
    img = misc.imread(file)

    return img

def kmeans(img, n_clusters=10):
    """Kmeans clustering technique for b&w images."""
    np.random.seed(0)

    X = img.reshape((-1, 1))  # We need an (n_sample, n_feature) array
    k_means = cluster.KMeans(n_clusters=n_clusters, n_init=4)
    k_means.fit(X)
    values = k_means.cluster_centers_.squeeze()
    labels = k_means.labels_

    # create an array from labels and values
    img_compressed = np.choose(labels, values)
    img_compressed.shape = img.shape

    return img_compressed

# %%
img1 = read_img('001', 'L', '1')
img2 = read_img('009', 'L', '4')
img3 = read_img('003', 'L', '2')
img4 = read_img('004', 'L', '2')

#
#   Images
#
plt.gray()
fig, ax = plt.subplots(2, 2)
plt.gray()
ax1, ax2, ax3, ax4 = ax.ravel()
ax1.imshow(img1)
ax1.set_title('img1')
ax2.imshow(img2)
ax2.set_title('img2')
ax3.imshow(img3)
ax3.set_title('img3')
ax4.imshow(img4)
ax4.set_title('img4')


#
#   Histograms
#
fig, ax = plt.subplots(2, 2)
ax1, ax2, ax3, ax4 = ax.ravel()
ax1.hist(img1.flatten(), 256)
ax1.set_title('img1 kmeans histo')
ax2.hist(img2.flatten(), 256)
ax2.set_title('img2 kmeans histo')
ax3.hist(img3.flatten(), 256)
ax3.set_title('img3 kmeans histo')
ax4.hist(img4.flatten(), 256)
ax4.set_title('img4 kmeans histo')

# %%
nb_clusters = 20
img1_k = kmeans(img1, nb_clusters)
img2_k = kmeans(img2, nb_clusters)
img3_k = kmeans(img3, nb_clusters)
img4_k = kmeans(img4, nb_clusters)

#
#   Kmeans
#
fig, ax = plt.subplots(2, 2)
plt.gray()
ax1, ax2, ax3, ax4 = ax.ravel()
ax1.imshow(img1_k)
ax1.set_title('img1 kmeans')
ax2.imshow(img2_k)
ax2.set_title('img2 kmeans')
ax3.imshow(img3_k)
ax3.set_title('img3 kmeans')
ax4.imshow(img4_k)
ax4.set_title('img4 kmeans')

#
#   Histograms
#
fig, ax = plt.subplots(2, 2)
ax1, ax2, ax3, ax4 = ax.ravel()
ax1.hist(img1_k.flatten(), 256)
ax1.set_title('img1 kmeans histo')
ax2.hist(img2_k.flatten(), 256)
ax2.set_title('img2 kmeans histo')
ax3.hist(img3_k.flatten(), 256)
ax3.set_title('img3 kmeans histo')
ax4.hist(img4_k.flatten(), 256)
ax4.set_title('img4 kmeans histo')

# %%
def segment_iris(img_k):
    mini_img_k = np.amin(img_k)
    img_iris = dilation(img_k < mini_img_k + 1, disk(3))
    return img_iris

iris1 = segment_iris(img1_k)
iris2 = segment_iris(img2_k)
iris3 = segment_iris(img3_k)
iris4 = segment_iris(img4_k)

def find_mean(iris):
    X, Y = [], []
    for i in range(iris.shape[0]):
        for j in range(iris.shape[1]):
            if iris[i][j]:
                X.append(i)
                Y.append(j)
    return np.mean(X), np.mean(Y)

fig, ax = plt.subplots(2, 2)
plt.gray()
ax1, ax2, ax3, ax4 = ax.ravel()
ax1.imshow(iris1)
x1, y1 = find_mean(iris1)
ax1.scatter(y1, x1, color='r')
ax1.set_title('img1 iris')
ax2.imshow(iris2)
x2, y2 = find_mean(iris2)
ax2.scatter(y2, x2, color='r')
ax2.set_title('img2 iris')
ax3.imshow(iris3)
x3, y3 = find_mean(iris3)
ax3.scatter(y3, x3, color='r')
ax3.set_title('img3 iris')
ax4.imshow(iris4)
x4, y4 = find_mean(iris4)
ax4.scatter(y4, x4, color='r')
ax4.set_title('img4 iris')

# %%
def clean_iris(iris, x, y):
    cleaned_iris = np.copy(iris)
    labels = label(iris)
    c = Counter(labels.flatten())
    label_iris = c.most_common(2)[1][0]
    clean_iris = labels == label_iris

    most_left = 0
    most_right = iris.shape[1] - 1
    sums = np.sum(clean_iris, axis=0)
    while sums[most_left] == 0:
        most_left += 1
    while sums[most_right] == 0:
        most_right -= 1
    radius = (most_right - most_left) // 2

    for i in range(iris.shape[0]):
        for j in range(iris.shape[1]):
            if np.linalg.norm([x - i, y - j]) > 1.1 * radius:
                cleaned_iris[i,j] = 0
    
    cleaned_iris[clean_iris] += 1

    cleaned_iris = dilation(cleaned_iris, disk(30))
    cleaned_iris = erosion(cleaned_iris, disk(30))
    cleaned_iris = erosion(cleaned_iris, disk(10))
    cleaned_iris = dilation(cleaned_iris, disk(10))
    #cleaned_iris = dilation(cleaned_iris, disk(1))
    
    most_left = 0
    most_right = iris.shape[1] - 1
    sums = np.sum(clean_iris, axis=0)
    while sums[most_left] == 0:
        most_left += 1
    while sums[most_right] == 0:
        most_right -= 1
    radius = (most_right - most_left) // 2
    
#    chull = convex_hull_image(cleaned_iris)
#    cleaned_iris[chull] += 1
    
    return cleaned_iris, radius

clean_iris1, rad1 = clean_iris(iris1, x1, y1)
clean_iris2, rad2 = clean_iris(iris2, x2, y2)
clean_iris3, rad3 = clean_iris(iris3, x3, y3)
clean_iris4, rad4 = clean_iris(iris4, x4, y4)
    
fig, ax = plt.subplots(2, 2)
plt.gray()
ax1, ax2, ax3, ax4 = ax.ravel()
ax1.imshow(clean_iris1)
ax1.set_title('img1 clean iris')
ax2.imshow(clean_iris2)
ax2.set_title('img2 clean iris')
ax3.imshow(clean_iris3)
ax3.set_title('img3 clean iris')
ax4.imshow(clean_iris4)
ax4.set_title('img4 clean iris')
# Out:
# /Users/lachaum/.pyenv/versions/p3/lib/python3.4/site-packages/ipykernel/__main__.py:22: DeprecationWarning: Implicitly casting between incompatible kinds. In a future numpy release, this will raise an error. Use casting="unsafe" if this is intentional.

# %%
from scipy.signal import convolve2d as conv2

def center(clean_iris, radius):
    ci = np.zeros(clean_iris.shape)
    ci[clean_iris] = 1
    d = disk(radius)
    t4 = conv2(ci, d, mode='same')
    maxi = np.amax(t4)
    for i in range(t4.shape[0]):
        for j in range(t4.shape[1]):
            if t4[i][j] == maxi:
                x_max = i
                y_max = j
    return x_max, y_max

# %%
center1_x, center1_y = center(clean_iris1, rad1)
center2_x, center2_y = center(clean_iris2, rad2)
center3_x, center3_y = center(clean_iris3, rad3)
center4_x, center4_y = center(clean_iris4, rad4)

# %%
fig, ax = plt.subplots(1, 2)
plt.gray()
ax1, ax2 = ax.ravel()
image = color.gray2rgb(clean_iris1)
circle = plt.Circle((center1_y, center1_x), rad1, fill=False, color='r')
ax1.add_artist(circle)
ax1.scatter(center1_y, center1_x, color='r')
ax1.imshow(image)
image = color.gray2rgb(img1)
circle = plt.Circle((center1_y, center1_x), rad1, fill=False, color='r')
ax2.add_artist(circle)
ax2.scatter(center1_y, center1_x, color='r')
ax2.imshow(image)

fig, ax = plt.subplots(1, 2)
plt.gray()
ax1, ax2 = ax.ravel()
image = color.gray2rgb(clean_iris2)
circle = plt.Circle((center2_y, center2_x), rad2, fill=False, color='r')
ax1.add_artist(circle)
ax1.scatter(center2_y, center2_x, color='r')
ax1.imshow(image)
image = color.gray2rgb(img2)
circle = plt.Circle((center2_y, center2_x), rad2, fill=False, color='r')
ax2.add_artist(circle)
ax2.scatter(center2_y, center2_x, color='r')
ax2.imshow(image)

fig, ax = plt.subplots(1, 2)
plt.gray()
ax1, ax2 = ax.ravel()
image = color.gray2rgb(clean_iris3)
circle = plt.Circle((center3_y, center3_x), rad3, fill=False, color='r')
ax1.add_artist(circle)
ax1.scatter(center3_y, center3_x, color='r')
ax1.imshow(image)
image = color.gray2rgb(img3)
circle = plt.Circle((center3_y, center3_x), rad3, fill=False, color='r')
ax2.add_artist(circle)
ax2.scatter(center3_y, center3_x, color='r')
ax2.imshow(image)

fig, ax = plt.subplots(1, 2)
plt.gray()
ax1, ax2 = ax.ravel()
image = color.gray2rgb(clean_iris4)
circle = plt.Circle((center4_y, center4_x), rad4, fill=False, color='r')
ax1.add_artist(circle)
ax1.scatter(center4_y, center4_x, color='r')
ax1.imshow(image)
image = color.gray2rgb(img4)
circle = plt.Circle((center4_y, center4_x), rad4, fill=False, color='r')
ax2.add_artist(circle)
ax2.scatter(center4_y, center4_x, color='r')
ax2.imshow(image)

plt.figure()
image = color.gray2rgb(img1)
circle = plt.Circle((center1_y, center1_x), rad1, fill=False, color='r')
plt.gca().add_artist(circle)
plt.scatter(center1_y, center1_x, color='r')
plt.imshow(image)

plt.figure()
image = color.gray2rgb(img2)
circle = plt.Circle((center2_y, center2_x), rad2, fill=False, color='r')
plt.gca().add_artist(circle)
plt.scatter(center2_y, center2_x, color='r')
plt.imshow(image)

plt.figure()
image = color.gray2rgb(img3)
circle = plt.Circle((center3_y, center3_x), rad3, fill=False, color='r')
plt.gca().add_artist(circle)
plt.scatter(center3_y, center3_x, color='r')
plt.imshow(image)

plt.figure()
image = color.gray2rgb(img4)
circle = plt.Circle((center4_y, center4_x), rad4, fill=False, color='r')
plt.gca().add_artist(circle)
plt.scatter(center4_y, center4_x, color='r')
plt.imshow(image)

# %%
from skimage.color import rgb2hsv, gray2rgb
from skimage.filters import median

it = np.copy(img3)
it_ad = equalize_adapthist(it)

nb_clusters = 20
itk = kmeans(it, nb_clusters)
itk_ad = kmeans(it_ad, nb_clusters)

nb_clusters_to_keep = 7
t_ad = sort(list(set(itk_ad.flatten())))
threshold = t_ad[nb_clusters_to_keep]
ii_ad = itk_ad <= threshold

# %%
ii_ad = dilation(erosion(ii_ad, disk(5)), disk(5))

plt.figure()
image = color.gray2rgb(ii_ad)
circle = plt.Circle((center3_y, center3_x), rad3, fill=False, color='r')
plt.gca().add_artist(circle)
circle = plt.Circle((center3_y, center3_x), 2 * rad3, fill=False, color='g')
plt.gca().add_artist(circle)
circle = plt.Circle((center3_y, center3_x), 350, fill=False, color='b')
plt.gca().add_artist(circle)
plt.scatter(center3_y, center3_x, color='r')
plt.imshow(image)
